# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
df = pd.read_csv("patent_result/web-search.csv")
# df.sort_values('被引用件数 (JP・US)', ascending=False)
df
# Out:
#                      id                                              title  \
# 0        US-10534818-B2  System and method for deep linking and search ...
# 1         US-8666965-B2  Web search with visited web page search result...
# 2      US-2016342695-A1  Personalization of web search results using te...
# 3        CN-110990688-B  Inserting local application search results int...
# 4         JP-6023276-B2  Selective addition of social aspects to web se...
# ...                 ...                                                ...
# 24995      CN-1311487-A                          用于自动把语境信息和多媒体资源相关联的方法和设备
# 24996     EP-1240605-A4  System und verfahren zum orten und anzeigen vo...
# 24997     FR-2800892-A1  SYSTEMS AND METHODS FOR PROVIDING SOFTWARE BAS...
# 24998      CN-1592903-A                        通过提供万维网文件布局图像简化因特网搜索的系统和方法
# 24999     EP-1134947-B1  Vorrichtung und Verfahren zum Session-Manageme...
#
# ...

# %%
# Out:
#                      id                                              title  \
# 0        US-10534818-B2  System and method for deep linking and search ...
# 1         US-8666965-B2  Web search with visited web page search result...
# 2      US-2016342695-A1  Personalization of web search results using te...
# 3        CN-110990688-B  Inserting local application search results int...
# 4         JP-6023276-B2  Selective addition of social aspects to web se...
# ...                 ...                                                ...
# 24995      CN-1311487-A                          用于自动把语境信息和多媒体资源相关联的方法和设备
# 24996     EP-1240605-A4  System und verfahren zum orten und anzeigen vo...
# 24997     FR-2800892-A1  SYSTEMS AND METHODS FOR PROVIDING SOFTWARE BAS...
# 24998      CN-1592903-A                        通过提供万维网文件布局图像简化因特网搜索的系统和方法
# 24999     EP-1134947-B1  Vorrichtung und Verfahren zum Session-Manageme...
#
# ...
